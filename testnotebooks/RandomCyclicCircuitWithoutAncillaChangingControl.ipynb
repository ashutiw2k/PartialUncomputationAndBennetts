# %%
from qiskit import QuantumCircuit, QuantumRegister

import rustworkx
from rustworkx.visualization import graphviz_draw
from rustworkx.rustworkx import simple_cycles
import collections
from collections import Counter
import copy

# %%
import os, sys

sys.path.append(os.path.abspath("../"))

num_i = 2
num_a = 2
num_o = 2

# %%
from helperfunctions.reversecircuitgraph import uncompute_input_nodes_greedy, add_uncomp_input_node, uncomp_all_operations_using_bennetts_in_circuitgraph
from helperfunctions.circuitgraphfunctions import get_computation_graph, get_uncomp_circuit
from helperfunctions.graphhelper import breakdown_qubit, edge_attr, node_attr
from helperfunctions.uncompfunctions import add_uncomputation, add_uncomputation_step
from helperfunctions.randomcircuit import random_quantum_circuit_type_2
from helperfunctions.constants import StringConstants, ListConstants

# %%
circ, d,a,g = random_quantum_circuit_type_2()
# Out:
# {Qubit(QuantumRegister(10, 'dq'), 0): [Qubit(QuantumRegister(10, 'dq'), 1), Qubit(QuantumRegister(10, 'dq'), 2), Qubit(QuantumRegister(10, 'dq'), 3), Qubit(QuantumRegister(10, 'dq'), 4), Qubit(QuantumRegister(10, 'dq'), 5), Qubit(QuantumRegister(10, 'dq'), 6), Qubit(QuantumRegister(10, 'dq'), 7), Qubit(QuantumRegister(10, 'dq'), 8), Qubit(QuantumRegister(10, 'dq'), 9), Qubit(QuantumRegister(12, 'aq'), 0), Qubit(QuantumRegister(12, 'aq'), 1), Qubit(QuantumRegister(12, 'aq'), 2), Qubit(QuantumRegister(12, 'aq'), 3), Qubit(QuantumRegister(12, 'aq'), 4), Qubit(QuantumRegister(12, 'aq'), 5), Qubit(QuantumRegister(12, 'aq'), 6), Qubit(QuantumRegister(12, 'aq'), 7), Qubit(QuantumRegister(12, 'aq'), 8), Qubit(QuantumRegister(12, 'aq'), 9), Qubit(QuantumRegister(12, 'aq'), 10), Qubit(QuantumRegister(12, 'aq'), 11)], Qubit(QuantumRegister(10, 'dq'), 1): [Qubit(QuantumRegister(10, 'dq'), 0), Qubit(QuantumRegister(10, 'dq'), 2), Qubit(QuantumRegister(10, 'dq'), 3), Qubit(QuantumRegister(10, 'dq'), 4), Qubit(QuantumRegister(10, 'dq'), 5), Qubit(QuantumRegister(10, 'dq'), 6), Qubit(QuantumRegister(10, 'dq'), 7), Qubit(QuantumRegister(10, 'dq'), 8), Qubit(QuantumRegister(10, 'dq'), 9), Qubit(QuantumRegister(12, 'aq'), 0), Qubit(QuantumRegister(12, 'aq'), 1), Qubit(QuantumRegister(12, 'aq'), 2), Qubit(QuantumRegister(12, 'aq'), 3), Qubit(QuantumRegister(12, 'aq'), 4), Qubit(QuantumRegister(12, 'aq'), 5), Qubit(QuantumRegister(12, 'aq'), 6), Qubit(QuantumRegister(12, 'aq'), 7), Qubit(QuantumRegister(12, 'aq'), 8), Qubit(QuantumRegister(12, 'aq'), 9), Qubit(QuantumRegister(12, 'aq'), 10), Qubit(QuantumRegister(12, 'aq'), 11)], Qubit(QuantumRegister(10, 'dq'), 2): [Qubit(QuantumRegister(10, 'dq'), 0), Qubit(QuantumRegister(10, 'dq'), 1), Qubit(QuantumRegister(10, 'dq'), 3), Qubit(QuantumRegister(10, 'dq'), 4), Qubit(QuantumRegister(10, 'dq'), 5), Qubit(QuantumRegister(10, 'dq'), 6), Qubit(QuantumRegister(10, 'dq'), 7), Qubit(QuantumRegister(10, 'dq'), 8), Qubit(QuantumRegister(10, 'dq'), 9), Qubit(QuantumRegister(12, 'aq'), 0), Qubit(QuantumRegister(12, 'aq'), 1), Qubit(QuantumRegister(12, 'aq'), 2), Qubit(QuantumRegister(12, 'aq'), 3), Qubit(QuantumRegister(12, 'aq'), 4), Qubit(QuantumRegister(12, 'aq'), 5), Qubit(QuantumRegister(12, 'aq'), 6), Qubit(QuantumRegister(12, 'aq'), 7), Qubit(QuantumRegister(12, 'aq'), 8), Qubit(QuantumRegister(12, 'aq'), 9), Qubit(QuantumRegister(12, 'aq'), 10), Qubit(QuantumRegister(12, 'aq'), 11)], Qubit(QuantumRegister(10, 'dq'), 3): [Qubit(QuantumRegister(10, 'dq'), 0), Qubit(QuantumRegister(10, 'dq'), 1), Qubit(QuantumRegister(10, 'dq'), 2), Qubit(QuantumRegister(10, 'dq'), 4), Qubit(QuantumRegister(10, 'dq'), 5), Qubit(QuantumRegister(10, 'dq'), 6), Qubit(QuantumRegister(10, 'dq'), 7), Qubit(QuantumRegister(10, 'dq'), 8), Qubit(QuantumRegister(10, 'dq'), 9), Qubit(QuantumRegister(12, 'aq'), 0), Qubit(QuantumRegister(12, 'aq'), 1), Qubit(QuantumRegister(12, 'aq'), 2), Qubit(QuantumRegister(12, 'aq'), 3), Qubit(QuantumRegister(12, 'aq'), 4), Qubit(QuantumRegister(12, 'aq'), 5), Qubit(QuantumRegister(12, 'aq'), 6), Qubit(QuantumRegister(12, 'aq'), 7), Qubit(QuantumRegister(12, 'aq'), 8), Qubit(QuantumRegister(12, 'aq'), 9), Qubit(QuantumRegister(12, 'aq'), 10), Qubit(QuantumRegister(12, 'aq'), 11)], Qubit(QuantumRegister(10, 'dq'), 4): [Qubit(QuantumRegister(10, 'dq'), 0), Qubit(QuantumRegister(10, 'dq'), 1), Qubit(QuantumRegister(10, 'dq'), 2), Qubit(QuantumRegister(10, 'dq'), 3), Qubit(QuantumRegister(10, 'dq'), 5), Qubit(QuantumRegister(10, 'dq'), 6), Qubit(QuantumRegister(10, 'dq'), 7), Qubit(QuantumRegister(10, 'dq'), 8), Qubit(QuantumRegister(10, 'dq'), 9), Qubit(QuantumRegister(12, 'aq'), 0), Qubit(QuantumRegister(12, 'aq'), 1), Qubit(QuantumRegister(12, 'aq'), 2), Qubit(QuantumRegister(12, 'aq'), 3), Qubit(QuantumRegister(12, 'aq'), 4), Qubit(QuantumRegister(12, 'aq'), 5), Qubit(QuantumRegister(12, 'aq'), 6), Qubit(QuantumRegister(12, 'aq'), 7), Qubit(QuantumRegister(12, 'aq'), 8), Qubit(QuantumRegister(1 ...
# Building Random Quantum Circuit with 10d, 12a, 50g: 100%|██████████| 50/50 [00:00<00:00, 149263.49it/s]

# %%
circ.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=1672x667>
